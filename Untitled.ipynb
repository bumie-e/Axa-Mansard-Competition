# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train_data.csv')
test = pd.read_csv('test_data.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7160 entries, 0 to 7159
# Data columns (total 14 columns):
# Customer Id           7160 non-null object
# YearOfObservation     7160 non-null int64
# Insured_Period        7160 non-null float64
# Residential           7160 non-null int64
# Building_Painted      7160 non-null object
# Building_Fenced       7160 non-null object
# Garden                7153 non-null object
# Settlement            7160 non-null object
# Building Dimension    7054 non-null float64
# Building_Type         7160 non-null int64
# Date_of_Occupancy     6652 non-null float64
# NumberOfWindows       7160 non-null object
# Geo_Code              7058 non-null object
# Claim                 7160 non-null int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 783.2+ KB

# %%
s = pd.read_csv('sample_submission.csv')
s.head()
# Out:
#   Customer Id  Claim
# 0          H0      1
# 1      H10000      1
# 2      H10001      1
# 3      H10002      1
# 4      H10003      1

# %%
vd = pd.read_csv('VariableDescription.csv')
pd.set_option('display.max_colwidth', 200) 
vd
# Out:
#               Variable  \
# 0          Customer Id
# 1    YearOfObservation
# 2       Insured_Period
# 3          Residential
# 4     Building_Painted
# 5      Building_Fenced
# 6               Garden
# 7           Settlement
# 8   Building Dimension
# 9        Building_Type
# 10   Date_of_Occupancy
# 11     NumberOfWindows
# 12            Geo Code
# 13               Claim
#
#                                                                                                          Description
# 0                                                                        Identification number for the Policy holder
# 1                                                                         year of observation for the insured policy
# 2   duration of insurance policy in Olusola Insurance. (Ex: Full year insurance, Policy Duration = 1; 6 months = 0.5
# 3                                                                      is the building a residential building or not
# 4                                                          is the building painted or not (N-Painted, V-Not Painted)
# 5                                                              is the building fence or not (N-Fenced, V-Not Fenced)
# 6                                                             building has garden or not (V-has garden; O-no garden)
# 7                                                 Area where the building is located. (R- rural area; U- urban area)
# 8                                                                                 Size of the insured building in m2
# 9                                                                             The type of building (Type 1, 2, 3, 4)
# 10                                                                                  date building was first occupied
# 11                                                                                 number of windows in the building
# 12                                                                         Geographical Code of the Insured building
# 13                                        target variable. (0: no claim, 1: at least one claim over insured period).

# %%
train.head()
# Out:
#   Customer Id  Insured_Period  Residential Building_Painted Building_Fenced  \
# 0      H14663             1.0            0                1               0
# 1       H2037             1.0            0                0               1
# 2       H3802             1.0            0                1               0
# 3       H3834             1.0            0                0               0
# 4       H5053             1.0            0                0               1
#
#    Garden  Building_Type NumberOfWindows Geo_Code  Claim  Age_of_Building  \
# 0       0              1               .     1053      0              0.0
# 1       1              1               4     1053      0              1.0
# 2       0              1               .     1053      0              0.0
# 3       0              1               .     1053      0              0.0
# 4       1              1               3     1053      0              1.0
#
#    Last_Visited  length_of_building
# 0             3               170.3
# 1             1               221.4
# 2             2               243.9
# 3             3               532.9
# 4             2               260.8

# %%
# bin insured period
# bin ageofbuilding
# convert building dmension to meters

# %%
n_train.ix[n_train.Building_Type == 1, ['Building_Painted', 'Building_Fenced', 'Residential', 'Garden', 'NumberOfWindows', 'length_of_building']] = 3
n_train.ix[n_train.Building_Type == 2, ['Building_Painted', 'Building_Fenced', 'Residential', 'Garden', 'NumberOfWindows', 'length_of_building']] = 0
n_train.ix[n_train.Building_Type == 3, ['Building_Painted', 'Building_Fenced', 'Residential', 'Garden', 'NumberOfWindows', 'length_of_building']] = 1
n_train.ix[n_train.Building_Type == 4, ['Building_Painted', 'Building_Fenced', 'Residential', 'Garden', 'NumberOfWindows', 'length_of_building']] = 2

n_test.ix[n_test.Building_Type == 1, ['Building_Painted', 'Building_Fenced', 'Residential', 'Garden', 'NumberOfWindows', 'length_of_building']] = 3
n_test.ix[n_test.Building_Type == 2, ['Building_Painted', 'Building_Fenced', 'Residential', 'Garden', 'NumberOfWindows', 'length_of_building']] = 0
n_test.ix[n_test.Building_Type == 3, ['Building_Painted', 'Building_Fenced', 'Residential', 'Garden', 'NumberOfWindows', 'length_of_building']] = 1
n_test.ix[n_test.Building_Type == 4, ['Building_Painted', 'Building_Fenced', 'Residential', 'Garden', 'NumberOfWindows', 'length_of_building']] = 2

n_train.Garden.fillna(2, inplace=True)
n_test.Garden.fillna(2, inplace=True)
# the 2 means not sure

# %%
train.Insured_Period.unique()
# Out:
# array([1., 0.])

# %%
train['Insured_Period'][train['Insured_Period'] < 0.5] = 0
train['Insured_Period'][train['Insured_Period'] > 0.49] = 1

# %%
train['Age_of_Building'] = 2016- train['Date_of_Occupancy']
train['Last_Visited'] = 2016-train['YearOfObservation']

# %%
train['Age_of_Building'][train['Age_of_Building'] < 117] = 0
train['Age_of_Building'][train['Age_of_Building'] > 116] = 1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7160 entries, 0 to 7159
# Data columns (total 12 columns):
# Insured_Period        7160 non-null float64
# Residential           7160 non-null int64
# Building_Painted      7160 non-null int64
# Building_Fenced       7160 non-null int64
# Garden                7160 non-null int64
# Building_Type         7160 non-null int64
# NumberOfWindows       7160 non-null int64
# Geo_Code              7160 non-null object
# Claim                 7160 non-null int64
# Age_of_Building       7160 non-null object
# Last_Visited          7160 non-null int64
# length_of_building    7160 non-null float64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 671.3+ KB

# %%
train.Geo_Code.values
# Out:
# array(['1053', '1053', '1053', ..., 1, 1, 1], dtype=object)

# %%
Id = train['Customer Id']
train.drop(['Customer Id'], axis=1, inplace=True)
for i in train.columns:
    if train[i].dtype == 'object':
        train[i] = pd.to_numeric(train[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2A004"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-0ef4e5b47cc3> in <module>
#       3 for i in train.columns:
#       4     if train[i].dtype == 'object':
# ----> 5         train[i] = pd.to_numeric(train[i])
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     133             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     134             values = lib.maybe_convert_numeric(values, set(),
# --> 135                                                coerce_numeric=coerce_numeric)
#     136
#     137     except Exception:
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2A004" at position 6990

# %%
train['Garden'][train['Garden'] == 'V'] = 0
train['Garden'][train['Garden'] == 'O'] = 1

train['Building_Painted'][train['Building_Painted'] == 'V'] = 0
train['Building_Painted'][train['Building_Painted'] == 'N'] = 1

train['Building_Fenced'][train['Building_Fenced'] == 'V'] = 0
train['Building_Fenced'][train['Building_Fenced'] == 'N'] = 1

# %%
train.drop(['Settlement', 'YearOfObservation', 'Date_of_Occupancy'], axis=1, inplace=True)

# %%
train.Garden.fillna(1, inplace=True)

# %%
train['length_of_building'] = 10 * (np.sqrt(train['Building Dimension']))
a = np.mean(train.length_of_building)
train.length_of_building.fillna(a, inplace=True)
train['length_of_building'] = train['length_of_building'].round(1)

# %%
train.NumberOfWindows.value_counts()
# Out:
#    .    3551
# 4        939
# 3        844
# 5        639
# 2        363
# 6        306
# 7        211
# 8        116
# 1         75
# >=10      67
# 9         49
# Name: NumberOfWindows, dtype: int64

# %%
for i in train.NumberOfWindows:
        train.NumberOfWindows = train.NumberOfWindows.replace('   .', 0)
        train.NumberOfWindows = train.NumberOfWindows.replace('>=10', 10)

# %%
pd.crosstab(train['NumberOfWindows'],train['Claim'], margins=True)
# Out:
# Claim               0     1   All
# NumberOfWindows
# 0                2819   732  3551
# 10                 32    35    67
# 1                  68     7    75
# 2                 323    40   363
# 3                 713   131   844
# 4                 717   222   939
# 5                 447   192   639
# 6                 201   105   306
# 7                 121    90   211
# 8                  61    55   116
# 9                  24    25    49
# All              5526  1634  7160

# %%
train.Geo_Code.fillna(1, inplace=True)

# %%
train.Age_of_Building.fillna(train.Age_of_Building.mode, inplace=True)

# %%
train.drop(['Building Dimension'], axis=1, inplace=True)

# %%
pd.crosstab(train['Garden'],train['Settlement'], margins=True)#.ix[30.0:116.0]

# %%
pd.crosstab(train['Garden'],train['Claim'], margins=True)#.ix[30.0:116.0]
# Out:
# Claim      0     1   All
# Garden
# O       2702   900  3602
# V       2819   732  3551
# All     5521  1632  7153

# %%
# plot of garden versus settlement
import seaborn as sns
def plot_graph(x, y):
    fig, ax = plt.subplots(figsize = (13, 4))
    sns.barplot(x, y)
    plt.xlabel('x', fontSize=13)
    plt.xticks(rotation='90')
    plt.ylabel('y', fontSize=13)
    plt.show()
    
plot_graph(train.Claim, train.Garden)

# %%
train['Garden'][train['Garden'] == 'V'] = 0
train['Garden'][train['Garden'] == 'O'] = 1

# %%
train.Claim.corr(train.Garden)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-e01f2d5eb11d> in <module>
# ----> 1 train.Claim.corr(train.Garden)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2103         if method in ['pearson', 'spearman', 'kendall'] or callable(method):
#    2104             return nanops.nancorr(this.values, other.values, method=method,
# -> 2105                                   min_periods=min_periods)
#    2106
#    2107         raise ValueError("method must be either 'pearson', "
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      74             try:
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#      78                 # we want to transform an object array
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nancorr(a, b, method, min_periods)
#    1100
#    1101     f = get_corr_func(method)
# -> 1102     return f(a, b)
#    1103
#    1104
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _pearson(a, b)
#    1110
#    1111     def _pearson(a, b):
# -> 1112         return np.corrcoef(a, b)[0, 1]
#    1113
#    1114     def _kendall(a, b):
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2520         warnings.warn('bias and ddof have no effect and are deprecated',
#    2521                       DeprecationWarning, stacklevel=2)
# -> 2522     c = cov(x, y, rowvar)
#    2523     try:
#    2524         d = diag(c)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2425             w *= aweights
#    2426
# -> 2427     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2428     w_sum = w_sum[0]
#    2429
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     425
#     426     if returned:
# --> 427         if scl.shape != avg.shape:
#     428             scl = np.broadcast_to(scl, avg.shape).copy()
#     429         return avg, scl
#
# AttributeError: 'float' object has no attribute 'shape'

# %%
train.ix[train.Settlement == 'U', 'Geo_Code'] = 1
train.ix[train.Settlement == 'R', 'Geo_Code'] = 0

# %%
pd.crosstab(train['Age_of_Building'],train['Settlement'], margins=True)#.ix[30.0:116.0]
# Out:
# Settlement          R     U   All
# Age_of_Building
# 0.0                 2     0     2
# 1.0                 8     0     8
# 2.0                 9     0     9
# 3.0                12     5    17
# 4.0                59     3    62
# 5.0                96     1    97
# 6.0                65     0    65
# 7.0                86     3    89
# 8.0                69     5    74
# 9.0                57     1    58
# 10.0               31     0    31
# 11.0               35     2    37
# 12.0               34     1    35
# 13.0               33     0    33
# 14.0               26     1    27
# 15.0               24     3    27
# 16.0               50     2    52
# 17.0               20     0    20
# 18.0               22     0    22
# 19.0               11     0    11
# 20.0               14     1    15
# 21.0               31     0    31
# 22.0               14     0    14
# 23.0                9     1    10
# 24.0               14     1    15
# 25.0               17     0    17
# 26.0               96     2    98
# 27.0               19     2    21
# 28.0               49   481   530
# 29.0               10     2    12
# ...               ...   ...   ...
# 116.0             366     5   371
# 118.0               4     0     4
# 120.0               3     0     3
# 121.0               4     0     4
# 123.0               2     0     2
# 126.0              15     1    16
# 132.0               1     0     1
# 136.0              10     0    10
# 141.0               4     0     4
# 145.0               2     0     2
# 146.0              14     3    17
# 152.0               1     0     1
# 156.0               3     0     3
# 166.0              49     0    49
# 170.0               1     0     1
# 176.0               1     0     1
# 186.0               4     0     4
# 192.0               1     0     1
# 196.0               1     0     1
# 206.0               3     0     3
# 216.0              24     0    24
# 236.0               1     0     1
# 266.0               3     0     3
# 298.0               2     0     2
# 316.0               8     2    10
# 403.0               1     0     1
# 416.0               5     0     5
# 466.0               1     0     1
# 471.0               1     0     1
# All              3609  3043  6652
#
# [135 rows x 3 columns]

# %%
pd.crosstab(train['Age_of_Building'],train['Claim'], margins=True)#.ix[30.0:116.0]
# Out:
# Claim               0     1   All
# Age_of_Building
# 0.0                 2     0     2
# 1.0                 8     0     8
# 2.0                 7     2     9
# 3.0                15     2    17
# 4.0                52    10    62
# 5.0                78    19    97
# 6.0                45    20    65
# 7.0                70    19    89
# 8.0                58    16    74
# 9.0                50     8    58
# 10.0               26     5    31
# 11.0               23    14    37
# 12.0               29     6    35
# 13.0               24     9    33
# 14.0               21     6    27
# 15.0               15    12    27
# 16.0               43     9    52
# 17.0               16     4    20
# 18.0               14     8    22
# 19.0                8     3    11
# 20.0               12     3    15
# 21.0               29     2    31
# 22.0                9     5    14
# 23.0                8     2    10
# 24.0               13     2    15
# 25.0                8     9    17
# 26.0               72    26    98
# 27.0               18     3    21
# 28.0              407   123   530
# 29.0                7     5    12
# ...               ...   ...   ...
# 116.0             293    78   371
# 118.0               3     1     4
# 120.0               2     1     3
# 121.0               3     1     4
# 123.0               1     1     2
# 126.0               9     7    16
# 132.0               1     0     1
# 136.0              10     0    10
# 141.0               3     1     4
# 145.0               1     1     2
# 146.0              14     3    17
# 152.0               0     1     1
# 156.0               3     0     3
# 166.0              34    15    49
# 170.0               1     0     1
# 176.0               0     1     1
# 186.0               4     0     4
# 192.0               0     1     1
# 196.0               1     0     1
# 206.0               3     0     3
# 216.0              21     3    24
# 236.0               1     0     1
# 266.0               2     1     3
# 298.0               2     0     2
# 316.0               9     1    10
# 403.0               0     1     1
# 416.0               5     0     5
# 466.0               1     0     1
# 471.0               1     0     1
# All              5120  1532  6652
#
# [135 rows x 3 columns]

# %%
train['Age_of_Building'] = abs(train['Date_of_Occupancy']-2016)

# %%
pd.crosstab(train['YearOfObservation'],train['Date_of_Occupancy'], margins=True)
# Out:
# Date_of_Occupancy  1545.0  1550.0  1600.0  1613.0  1700.0  1718.0  1750.0  \
# YearOfObservation
# 2012                    0       0       0       1       0       1       1
# 2013                    0       1       1       0       1       0       0
# 2014                    1       0       0       0       4       1       1
# 2015                    0       0       2       0       1       0       0
# 2016                    0       0       2       0       4       0       1
# All                     1       1       5       1      10       2       3
#
# Date_of_Occupancy  1780.0  1800.0  1810.0  ...  2008.0  2009.0  2010.0  \
# YearOfObservation                          ...
# 2012                    0       5       0  ...      25      23      15
# 2013                    0       2       0  ...      18      22      17
# 2014                    1       7       0  ...      16      21       8
# 2015                    0       7       2  ...      10      12      12
# 2016                    0       3       1  ...       5      11      13
# All                     1      24       3  ...      74      89      65
#
# Date_of_Occupancy  2011.0  2012.0  2013.0  2014.0  2015.0  2016.0   All
# YearOfObservation
# 2012                   21      11       0       0       0       0  1693
# 2013                   20      17       4       0       0       0  1682
# 2014                   14      15       5       1       0       0  1290
# 2015                   26      11       5       4       2       0   993
# 2016                   16       8       3       4       6       2   994
# All                    97      62      17       9       8       2  6652
#
# [6 rows x 135 columns]

# %%
pd.crosstab(train['Claim'],train['Building_Type'], margins=True)
# Out:
# Building_Type     1     2     3    4   All
# Claim
# 0              1412  2593   919  602  5526
# 1               304   712   311  307  1634
# All            1716  3305  1230  909  7160

# %%
pd.crosstab(train['Settlement'],train['Building_Type'], margins=True)
# Out:
# Building_Type     1     2     3    4   All
# Settlement
# R               853  1638   645  474  3610
# U               863  1667   585  435  3550
# All            1716  3305  1230  909  7160

# %%
pd.pivot_table(train, values='Claim', index=['Settlement'], columns=['Building_Type'])
# Out:
# Building_Type         1         2         3         4
# Settlement
# R              0.185229  0.235043  0.283721  0.371308
# U              0.169177  0.196161  0.218803  0.301149

# %%
train.pivot_table(index=['Residential','Insured_Period'], columns='Settlement')
# Out:
#                            Building Dimension              Building_Type  \
# Settlement                                  R            U             R
# Residential Insured_Period
# 0           0.000000              1508.750000  1362.056180      2.583333
#             0.002732              4760.000000          NaN      1.000000
#             0.010929               190.000000          NaN      2.000000
#             0.016393                      NaN   990.000000           NaN
#             0.021918               800.000000   150.000000      2.000000
#             0.024658                      NaN   400.000000           NaN
#             0.030055              2300.000000          NaN      2.000000
#             0.030137                      NaN          NaN           NaN
#             0.032787              3700.000000          NaN      1.000000
#             0.035616                      NaN          NaN           NaN
#             0.038251                      NaN   912.000000           NaN
#             0.038356               335.000000   400.000000      2.000000
#             0.043836               250.000000          NaN      2.000000
#             0.046448              4100.000000          NaN      1.000000
#             0.049180              2690.000000          NaN      1.000000
#             0.051913                      NaN  1450.000000           NaN
#             0.052055                      NaN  1220.000000           NaN
#             0.054795                      NaN   416.000000           NaN
#             0.057534               523.000000          NaN      1.000000
#             0.060109              1400.000000          NaN      1.000000
#             0.915301        2012.000000
#             0.917808        2013.000000
#             0.920765        2016.000000
#             0.923288                NaN
#             0.928962                NaN
#             0.942623                NaN
#             0.950685        2015.000000
#             0.950820                NaN
#             0.953425        2014.000000
#             0.958904        2015.000000
#             0.961644        2013.500000
#             0.961749        2012.000000
#             0.964384                NaN
#             0.967213        2016.000000
#             0.972678                NaN
#             0.983562        2015.000000
#             0.986301        2015.000000
#             0.994536                NaN
#             0.997260        2014.000000
#             0.997268        2015.920000
#             1.000000        2013.194485
#
# [512 rows x 12 columns]

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])

# %%
 pd.crosstab(train['Claim'],train['Settlement'], margins=True)
# Out:
# Settlement     R     U   All
# Claim
# 0           2708  2818  5526
# 1            902   732  1634
# All         3610  3550  7160

# %%
 pd.crosstab(train['Claim'],train['Insured_Period'], margins=True)
# Out:
# Insured_Period  0.0  0.00273224  0.010928962  0.016393443  \
# Claim
# 0               139           1            1            2
# 1                26           0            0            0
# All             165           1            1            2
#
# Insured_Period  0.021917807999999997  0.024590163999999998  0.024657534  \
# Claim
# 0                                  3                     1            1
# 1                                  0                     0            0
# All                                3                     1            1
#
# Insured_Period  0.030054645  0.030136986  0.032786885  ...  0.98630137  \
# Claim                                                  ...
# 0                         1            1            0  ...           6
# 1                         0            0            1  ...           0
# All                       1            1            1  ...           6
#
# Insured_Period  0.9890410959999999  0.989071038  0.9917808220000001  \
# Claim
# 0                                2            6                   1
# 1                                0            0                   0
# All                              2            6                   1
#
# Insured_Period  0.994520548  0.994535519  0.9972602740000001  0.99726776  \
# Claim
# 0                         1           20                  19         418
# 1                         0            4                   7         129
# All                       1           24                  26         547
#
# Insured_Period   1.0   All
# Claim
# 0               4024  5526
# 1               1301  1634
# All             5325  7160
#
# [3 rows x 402 columns]

# %%
 pd.crosstab(train['Settlement'],train['Residential'], margins=True)
# Out:
# Residential     0     1   All
# Settlement
# R            2371  1239  3610
# U            2602   948  3550
# All          4973  2187  7160

# %%
 pd.crosstab(train['Settlement'],train['Garden'], margins=True) 
    # All urban has garden
# Out:
# Garden         O     V   All
# Settlement
# R           3602     1  3603
# U              0  3550  3550
# All         3602  3551  7153

# %%
 pd.crosstab(train['Claim'],train['Building_Fenced'], margins=True) 
    # all urban has fenced house
# Out:
# Building_Fenced     N     V   All
# Claim
# 0                2707  2819  5526
# 1                 901   733  1634
# All              3608  3552  7160

# %%
#a.a.corr(a.r)
train.corr()
# Out:
#                     YearOfObservation  Insured_Period  Residential  \
# YearOfObservation            1.000000        0.025434    -0.040391
# Insured_Period               0.025434        1.000000    -0.037620
# Residential                 -0.040391       -0.037620     1.000000
# Building Dimension           0.009128        0.007473     0.057481
# Building_Type                0.005490       -0.017811     0.334039
# Date_of_Occupancy           -0.029492       -0.003445    -0.042058
# Geo_Code                    -0.120103       -0.046504    -0.082684
# Claim                       -0.016367        0.088715     0.063509
# Age_of_Building              0.029492        0.003445     0.042058
#
#                     Building Dimension  Building_Type  Date_of_Occupancy  \
# YearOfObservation             0.009128       0.005490          -0.029492
# Insured_Period                0.007473      -0.017811          -0.003445
# Residential                   0.057481       0.334039          -0.042058
# Building Dimension            1.000000       0.007935           0.207624
# Building_Type                 0.007935       1.000000          -0.146608
# Date_of_Occupancy             0.207624      -0.146608           1.000000
# Geo_Code                     -0.132320      -0.020320           0.171117
# Claim                         0.297089       0.112168           0.019170
# Age_of_Building              -0.207624       0.146608          -1.000000
#
#                     Geo_Code     Claim  Age_of_Building
# YearOfObservation  -0.120103 -0.016367         0.029492
# Insured_Period     -0.046504  0.088715         0.003445
# Residential        -0.082684  0.063509         0.042058
# Building Dimension -0.132320  0.297089        -0.207624
# Building_Type      -0.020320  0.112168         0.146608
# Date_of_Occupancy   0.171117  0.019170        -1.000000
# Geo_Code            1.000000 -0.052019        -0.171117
# Claim              -0.052019  1.000000        -0.019170
# Age_of_Building    -0.171117 -0.019170         1.000000

# %%
pd.crosstab(train['Settlement'],train['Building_Painted'], margins=True)
# Out:
# Building_Painted     N     V   All
# Settlement
# R                    7  3603  3610
# U                 1771  1779  3550
# All               1778  5382  7160

# %%
# plot of geo_code versus settlement
import seaborn as sns
def plot_graph(x, y):
    fig, ax = plt.subplots(figsize = (13, 4))
    sns.barplot(x, y)
    plt.xlabel('x', fontSize=13)
    plt.xticks(rotation='90')
    plt.ylabel('Geo_Code', fontSize=13)
    plt.show()
    
plot_graph(train.Claim, train.Age_of_Building)

# %%
train1['Garden'][train1['Garden'] == 'V'] = 0
train1['Garden'][train1['Garden'] == 'O'] = 1
train1['Building_Painted'][train1['Building_Painted'] == 'V'] = 0
train1['Building_Painted'][train1['Building_Painted'] == 'N'] = 1
train1['Building_Fenced'][train1['Building_Fenced'] == 'V'] = 0
train1['Building_Fenced'][train1['Building_Fenced'] == 'N'] = 1
#train1['Garden'][train1['Garden'] == 'Not_Sure'] = 1


test2['Garden'][test2['Garden'] == 'V'] = 0
test2['Garden'][test2['Garden'] == 'O'] = 1
test2['Building_Painted'][test2['Building_Painted'] == 'V'] = 0
test2['Building_Painted'][test2['Building_Painted'] == 'N'] = 1
test2['Building_Fenced'][test2['Building_Fenced'] == 'V'] = 0
test2['Building_Fenced'][test2['Building_Fenced'] == 'N'] = 1
#test1['Marital_Status'][test1['Marital_Status'] == 'Not_Sure'] = 1

# %%
train1['Building Dimension'] = train1['Building Dimension'].fillna(train1['Building Dimension'].median())

test2['Building Dimension'] = test2['Building Dimension'].fillna(test2['Building Dimension'].median())

# %%
train1['Garden'] = train1['Garden'].fillna(train1['Garden'].median())
train1['Date_of_Occupancy'] = train1['Date_of_Occupancy'].fillna(train1['Date_of_Occupancy'].median())
#train1['Geo_Code'] = train1['Geo_Code'].fillna(train1['Geo_Code'].median())

test2['Garden'] = test2['Garden'].fillna(test2['Garden'].median())
test2['Date_of_Occupancy'] = test2['Date_of_Occupancy'].fillna(test2['Date_of_Occupancy'].median())
#test2['Geo_Code'] = test2['Geo_Code'].fillna(test2['Geo_Code'].median())

# %%
train1['Settlement'][train1['Settlement'] == 'U'] = 0
train1['Settlement'][train1['Settlement'] == 'R'] = 1

test2['Settlement'][test2['Settlement'] == 'U'] = 0
test2['Settlement'][test2['Settlement'] == 'R'] = 1

# %%
year_of_building = train1.YearOfObservation - train1.Date_of_Occupancy
train1['year_of_building'] = year_of_building
train1.drop(['YearOfObservation', 'Date_of_Occupancy'], axis=1, inplace=True)

# %%
year_of_building1 = test2.YearOfObservation - test2.Date_of_Occupancy
test2['year_of_building'] = year_of_building1
test2.drop(['YearOfObservation', 'Date_of_Occupancy'], axis=1, inplace=True)

# %%
length_of_building = np.sqrt(train1['Building Dimension'])
length_of_building = 2 * length_of_building
length_of_building = length_of_building.astype(int)
train1['length_of_building'] = length_of_building

# %%
length_of_building1 = np.sqrt(test2['Building Dimension'])
length_of_building1 = 2 * length_of_building1
length_of_building1 = length_of_building1.astype(int)
test2['length_of_building'] = length_of_building1

# %%
train1.drop(['Building Dimension'], axis=1, inplace=True)

# %%
test2.drop(['Building Dimension'], axis=1, inplace=True)

# %%
new_ins_period = train1.Insured_Period * 1000
train1['new_ins_period'] = new_ins_period.astype(int)
train1.drop(['Insured_Period'], axis=1, inplace=True)

# %%
new_ins_period2 = test2.Insured_Period * 1000
test2['new_ins_period'] = new_ins_period2.astype(int)
test2.drop(['Insured_Period'], axis=1, inplace=True)

# %%
for i in train1['NumberOfWindows']:
    train1['NumberOfWindows'] = train1['NumberOfWindows'].replace("   .", '0')
    train1['NumberOfWindows'] = train1['NumberOfWindows'].replace('>=10', '10')
    train1.Geo_Code = train1['Geo_Code'].replace('nan', '0000')

# %%
train1.Geo_Code.values

# %%
for i in train1['Geo_Code']:
    if i == 'nan' :
        train1.Geo_Code = train1['Geo_Code'].replace('nan', '0000')

# %%
for i in test2['NumberOfWindows']:
    test2['NumberOfWindows'] = test2['NumberOfWindows'].replace("   .", '0')
    test2['NumberOfWindows'] = test2['NumberOfWindows'].replace('>=10', '10')
    train1.Geo_Code = train1['Geo_Code'].replace('nan', '0000')

# %%
"   ." in train1['NumberOfWindows']

# %%
train1.isnull()

# %%
test2.drop('Geo_Code', axis=1, inplace=True)

# %%
train1.drop('Geo_Code', axis=1, inplace=True)

# %%
train1.info()

# %%
train1.Residential.unique()

# %%
train1.Building_Painted.unique()

# %%
train1.Building_Fenced.unique()

# %%
train1.Garden.unique()

# %%
train1.Settlement.unique()

# %%
train1.Building_Type.unique()

# %%
train1.NumberOfWindows.unique()

# %%
target.unique()

# %%
train1.year_of_building.unique()

# %%
train1.length_of_building.unique()

# %%
train1 = pd.get_dummies(train1, columns=['NumberOfWindows', 'Building_Type'])
test2 = pd.get_dummies(test2, columns=['NumberOfWindows', 'Building_Type'])

# %%
train1.Building_Painted = pd.to_numeric(train1.Building_Painted)
train1.Building_Fenced = pd.to_numeric(train1.Building_Fenced)
#train1.Settlement = pd.to_numeric(train1.Settlement)
#train1.NumberOfWindows = pd.to_numeric(train1.NumberOfWindows)


test2.Building_Painted = pd.to_numeric(test2.Building_Painted)
test2.Building_Fenced = pd.to_numeric(test2.Building_Fenced)
test2.Settlement = pd.to_numeric(test2.Settlement)
#test2.NumberOfWindows = pd.to_numeric(test2.NumberOfWindows)

# %%
train1.new_ins_period.unique()

# %%
train1.head()

# %%
# lets assign a variable to EmployeeNo and drop it
target_Id = test2['Customer Id']
train1.drop(['Customer Id'], axis=1, inplace=True)
test2.drop(['Customer Id'], axis=1, inplace=True)

# %%
target = train1.Claim
train1.drop(['Claim'], axis=1, inplace=True)

# %%
train1.to_csv('train1.csv')
test2.to_csv('test2.csv')
target.to_csv('target.csv')

# %%
train1 = pd.read_csv('wbd_train.csv')
test2 = pd.read_csv('wbd_test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-157b8c5e3d2f> in <module>
# ----> 1 train1 = pd.read_csv('wbd_train.csv')
#       2 test2 = pd.read_csv('wbd_test.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'wbd_train.csv' does not exist: b'wbd_train.csv'

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test= train_test_split(train1, target, test_size = 0.20, random_state =0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6cdfb42a35dc> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test, y_train,y_test= train_test_split(train1, target, test_size = 0.20, random_state =0)
#
# NameError: name 'train1' is not defined

# %%
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.ensemble import GradientBoostingClassifier

# import the tools for metrics
from sklearn import metrics #accuracy measure
from sklearn.metrics import accuracy_score, precision_score, f1_score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
lr = LogisticRegression(solver='lbfgs')

lr.fit(x_train, y_train)
lr_probs = lr.predict(x_test)
roc_auc_score(y_test, lr_probs)

# %%
ns_auc = roc_auc_score(y_test, ns_probs)
lr_auc = roc_auc_score(y_test, lr_probs)

# %%
lr_probs

# %%
# predict using the X_test
pred1 = lr.predict_proba(x_test)

# %%
# see the overall performance of the data
from sklearn.metrics import classification_report
print('çlassification_report')
print(classification_report(lr_probs, y_test))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, lr_probs))

# %%
pre2 = xgb.predict(test2)

# %%
# Lets Export It To A Csv File
output = pd.DataFrame(data = {'Customer Id':target_Id, 'Claim':pre2})
output.to_csv(path_or_buf = 'hack2.csv', index = False, quoting = 3)

# %%
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, pred1)

# %%
model = GradientBoostingClassifier(learning_rate = 0.01, n_estimators = 500, random_state=300, max_features='auto', max_depth=10)
model.fit(x_train, y_train) 
print('Accuracy score for x_train is ', model.score(x_train, y_train))
print('Accuracy score for x_test is ', model.score(x_test, y_test))

# %%
pre1 = model.predict(x_test)
roc_auc_score(y_test, pre1)

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(learning_rate = 0.01, num_boosting_rounds = 500 , max_depth=10, subsample=0.8)
xgb.fit(x_train, y_train)
print('The Accuracy Score For x_test Is : ', xgb.score(x_test, y_test)), print('The Accuracy Score For x_train Is : ', xgb.score(x_train, y_train))

# %%
pred3 = xgb.predict(x_test)
roc_auc_score(y_test, pred3)

# %%
pred3a = xgb.predict(test2)

# Lets Export It To A Csv File
output = pd.DataFrame(data = {'Customer Id':target_Id, 'Claim':pred3a})
output.to_csv(path_or_buf = 'hack4.csv', index = False, quoting = 3)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, pred3))

# %%
import catboost
print(catboost.__version__)


X = train1
y = target

cat_features = list(range(0, X.shape[1]))
print(cat_features)

from catboost import CatBoostClassifier
model = CatBoostClassifier(iterations=100)
model.fit(X, y, cat_features=cat_features, verbose=10)

model.predict_proba(X)

# %%
pre2 = model.predict(X)

# %%
pree = model.predict(test2)

# %%
# Lets Export It To A Csv File
output = pd.DataFrame(data = {'Customer Id':target_Id, 'Claim':pree})
output.to_csv(path_or_buf = 'hack6.csv', index = False, quoting = 3)

# %%
pree.sum()

# %%
np.set_printoptions(precision=4)

from sklearn.model_selection import train_test_split

data = train_test_split(X, y, test_size=0.25, random_state=0)
x_train, x_validation, y_train, y_validation = data

cat_features = list(range(0, X.shape[1]))
print(cat_features)
from catboost import Pool
pool = Pool(data=X, label=y)

train_pool = Pool(
    data=x_train, 
    label=y_train
)

validation_pool = Pool(
    data=x_validation, 
    label=y_validation
)

# %%
model = CatBoostClassifier(
    iterations=1000,
    learning_rate=0.001,
    loss_function='CrossEntropy'
)
model.fit(train_pool, eval_set=validation_pool, verbose=False)
per1 = model.predict(x_test)
print(roc_auc_score(y_test, per1))
print('Model is fitted: {}'.format(model.is_fitted()))
print('Model params:\n{}'.format(model.get_params()))

# %%
prem  = model.predict(x_test)
roc_auc_score(y_test, prem)
pre = model.predict(test2)

# %%
model = CatBoostClassifier(
    iterations=,
#     verbose=5,
)
model.fit(train_pool, eval_set=validation_pool);

# %%
model1 = CatBoostClassifier(
    iterations=1000,
    learning_rate=0.002,
    custom_loss=['AUC']
)

model1.fit(
    train_pool,
    eval_set=validation_pool,
    verbose=False,
    plot=True
);

# %%
prem  = model1.predict(x_test)
roc_auc_score(y_test, prem)
pre = model1.predict(test2)

# %%
roc_auc_score(y_test, prem)

# %%
pre = model.predict(test2)

# %%
model1 = CatBoostClassifier(
    learning_rate=0.7,
    iterations=100,
    train_dir='learing_rate_0.7'
)

model2 = CatBoostClassifier(
    learning_rate=0.01,
    iterations=100,
    train_dir='learing_rate_0.01'
)

model1.fit(train_pool, eval_set=validation_pool, verbose=20)
model2.fit(train_pool, eval_set=validation_pool, verbose=20);

# %%
# Lets Export It To A Csv File
output = pd.DataFrame(data = {'Customer Id':target_Id, 'Claim':pre})
output.to_csv(path_or_buf = 'hack7.csv', index = False, quoting = 3)

# %%
from catboost import MetricVisualizer
MetricVisualizer(['learing_rate_0.7', 'learing_rate_0.01']).start()

# %%
model = CatBoostClassifier(
    iterations=100,
#     use_best_model=False
)
model.fit(
    train_pool,
    eval_set=validation_pool,
    verbose=False,
    plot=True
);

# %%
print('Tree count: ' + str(model.tree_count_))

# %%
model_with_early_stop = CatBoostClassifier(
    iterations=200,
    learning_rate=0.5,
    early_stopping_rounds=20
)

model_with_early_stop.fit(
    train_pool,
    eval_set=validation_pool,
    verbose=False,
    plot=True
);

# %%
print(model_with_early_stop.tree_count_)

# %%
tunned_model = CatBoostClassifier(
    iterations=1000,
    learning_rate=0.001,
    depth=10,
    l2_leaf_reg=3,
    random_strength=5,
    bagging_temperature=1
    logloss= 'AUC'
)

tunned_model.fit(
    X_train, y_train,
    verbose=False,
    eval_set=(X_validation, y_validation),
    plot=True
);

# %%
pred = tunned_model.predict(x_test)

# %%
roc_auc_score(y_test, pred)

# %%
pred1a = tunned_model.predict(test2)

# %%
# Lets Export It To A Csv File
output = pd.DataFrame(data = {'Customer Id':target_Id, 'Claim':pred1a})
output.to_csv(path_or_buf = 'hack5.csv', index = False, quoting = 3)

# %%
from sklearn.cluster import KMeans
wc = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init = 'k-means++', n_init=10, random_state=0)
    kmeans.fit(x_train)
    wc.append(kmeans.inertia_)
plt.plot(range(1, 11), wc)
plt.title('My very first kmeans')
plt.xlabel('Using the Elbow method')
plt.ylabel('wc')
plt.show()

# %%
kmeans = KMeans(n_clusters=2, init='k-means++', max_iter=300, random_state=0)
y_kmeans=kmeans.fit_predict(x_train)
